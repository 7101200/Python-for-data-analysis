# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd

# %%
pd.read_csv('ex1.csv',encoding='gbk')
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
pd.read_table('ex1.csv',encoding='gbk',sep=',')
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
pd.read_csv('ex2.csv',encoding='gbk',header=None)
# Out:
#           0     1     2     3     4
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
colNames = ['商品编号','进货价格','销售价格','销售数量','商品名称']
pd.read_csv('ex2.csv',encoding='gbk',names=colNames)
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
pd.read_csv('ex2.csv',encoding='gbk',names=colNames,index_col='商品编号')
# Out:
#           进货价格  销售价格  销售数量  商品名称
# 商品编号
# X1000001   782   998  5303  小米手机
# X1000002  1248  1699  2200  智能电视
# X1000003   892  1218  4310  智能空调

# %%
pd.read_csv('csv_mindex.csv',encoding='gbk',index_col=['生产厂商','产品类别'])
# Out:
#              价格     销量
# 生产厂商 产品类别
# 小米科技 智能手机  1099  43000
#      智能电视  3999   5031
#      智能空调  1599  60030
#      智能手环   299  71300
# 华为科技 智能手机  1199  32330
#      智能电视  3899   3002
#      智能空调  1399  40020
#      智能手环   219  52100

# %%
pd.read_table('ex3.txt',sep='\s+')
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
pd.read_csv('ex4.csv',encoding='gbk')
# Out:
#            # 商品的列名 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0             商品编号       进货价格       销售价格       销售数量       商品名称
# 1     # 这些是商品的相关信息        NaN        NaN        NaN        NaN
# 2  # 使用的是CSV文件进行存储        NaN        NaN        NaN        NaN
# 3         X1000001        782        998       5303       小米手机
# 4         X1000002       1248       1699       2200       智能电视
# 5         X1000003        892       1218       4310       智能空调

# %%
pd.read_csv('ex4.csv',encoding='gbk',skiprows=[0,2,3])
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
pd.read_csv('ex5.csv',encoding='gbk')
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# 5     1.817480  0.742273  0.419395 -2.251035   Q
# 6    -0.776764  0.935518 -0.332872 -1.875641   U
# 7    -0.913135  1.530624 -0.572657  0.477252   K
# 8     0.358480 -0.497572 -0.367016  0.507702   S
# 9    -1.740877 -1.160417 -1.637830  2.172201   G
# 10    0.240564 -0.328249  1.252155  1.072796   8
# 11    0.764018  1.165476 -0.639544  1.495258   R
# 12    0.571035 -0.310537  0.582437 -0.298765   1
# 13    2.317658  0.430710 -1.334216  0.199679   P
# 14    1.547771 -1.119753 -2.277634  0.329586   J
# 15   -1.310608  0.401719 -1.000987  1.156708   E
# 16   -0.088496  0.634712  0.153324  0.415335   B
# 17   -0.018663 -0.247487 -1.446522  0.750938   A
# ...

# %%
pd.read_csv('ex5.csv',encoding='gbk',nrows=50)
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# 5   1.817480  0.742273  0.419395 -2.251035   Q
# 6  -0.776764  0.935518 -0.332872 -1.875641   U
# 7  -0.913135  1.530624 -0.572657  0.477252   K
# 8   0.358480 -0.497572 -0.367016  0.507702   S
# 9  -1.740877 -1.160417 -1.637830  2.172201   G
# 10  0.240564 -0.328249  1.252155  1.072796   8
# 11  0.764018  1.165476 -0.639544  1.495258   R
# 12  0.571035 -0.310537  0.582437 -0.298765   1
# 13  2.317658  0.430710 -1.334216  0.199679   P
# 14  1.547771 -1.119753 -2.277634  0.329586   J
# 15 -1.310608  0.401719 -1.000987  1.156708   E
# 16 -0.088496  0.634712  0.153324  0.415335   B
# 17 -0.018663 -0.247487 -1.446522  0.750938   A
# 18 -0.070127 -1.579097  0.120892  0.671432   F
# ...

# %%
pd.read_csv('ex5.csv',encoding='gbk',chunksize=200)

# %%
readData = pd.read_csv('ex5.csv',encoding='gbk',nrows=200)
readData[100:150]
# Out:
#           one       two     three      four key
# 100 -0.602748 -0.182504 -0.768164  1.260686   X
# 101 -0.039105 -0.069510 -1.358052 -0.292859   0
# 102 -0.345101 -0.179477 -0.904658 -0.071287   T
# 103 -0.759495  0.225916  2.235872 -0.004490   X
# 104 -1.686771  0.742276  0.485876  1.798507   Q
# 105  0.145697  0.805037  0.350362 -0.540235   O
# 106  2.487654 -0.147867  0.580688 -0.305696   S
# 107  0.380166 -0.592483  0.393693 -0.463217   M
# 108  0.963549 -1.550302 -0.944962  0.121546   K
# 109 -0.040385 -0.312649 -1.196604  1.075043   S
# 110  0.938357 -0.235761 -0.077360  1.162150   4
# 111  0.190303 -0.425473  0.362347 -0.688711   U
# 112  0.256419  0.082669 -2.302758 -0.446115   6
# 113  0.690972  0.871498  0.948469  0.644683   7
# 114 -1.157781  0.093696 -0.765273 -0.724767   Q
# 115 -0.295462 -0.832817  1.490204 -0.420786   F
# 116  0.132723 -1.255780  1.370008  1.144490   I
# 117 -0.111381  0.572076  1.807962  1.090205   N
# 118  0.178700 -1.608832  2.174615 -1.351738   6
# ...

# %%
chunks = pd.read_csv('ex5.csv',encoding='gbk',chunksize=200)
for i in chunks:
    print(i[160:180])
# Out:
# RangeIndex(start=0, stop=200, step=1)
# RangeIndex(start=200, stop=400, step=1)
# RangeIndex(start=400, stop=600, step=1)
# RangeIndex(start=600, stop=800, step=1)
# RangeIndex(start=800, stop=1000, step=1)
# RangeIndex(start=1000, stop=1200, step=1)
# RangeIndex(start=1200, stop=1400, step=1)
# RangeIndex(start=1400, stop=1600, step=1)
# RangeIndex(start=1600, stop=1800, step=1)
# RangeIndex(start=1800, stop=2000, step=1)
# RangeIndex(start=2000, stop=2200, step=1)
# RangeIndex(start=2200, stop=2400, step=1)
# RangeIndex(start=2400, stop=2600, step=1)
# RangeIndex(start=2600, stop=2800, step=1)
# RangeIndex(start=2800, stop=3000, step=1)
# RangeIndex(start=3000, stop=3200, step=1)
# RangeIndex(start=3200, stop=3400, step=1)
# RangeIndex(start=3400, stop=3600, step=1)
# RangeIndex(start=3600, stop=3800, step=1)
# RangeIndex(start=3800, stop=4000, step=1)
# RangeIndex(start=4000, stop=4200, step=1)
# RangeIndex(start=4200, stop=4400, step=1)
# ...

# %%
chunks = pd.read_csv('ex5.csv',encoding='gbk',chunksize=200)
vals = Series([])
for i in chunks:
    vals = vals.add(i['key'].value_counts(),fill_value=0)
vals
# Out:
# 0    151.0
# 1    146.0
# 2    152.0
# 3    162.0
# 4    171.0
# 5    157.0
# 6    166.0
# 7    164.0
# 8    162.0
# 9    150.0
# A    320.0
# B    302.0
# C    286.0
# D    320.0
# E    368.0
# F    335.0
# G    308.0
# H    330.0
# I    327.0
# J    337.0
# K    334.0
# L    346.0
# M    338.0
# N    306.0
# O    343.0
# P    324.0
# Q    340.0
# R    318.0
# S    308.0
# T    304.0
# U    326.0
# V    328.0
# W    305.0
# X    364.0
# Y    314.0
# Z    288.0
# dtype: float64

# %%
data = pd.read_csv('ex6.csv',encoding='gbk')
data
# Out:
#   销售热度      商品编号   进货价格  销售价格  销售数量  商品名称
# 0   热销  X1000001  782.0   998  5303   NaN
# 1   推广  X1000002    NaN  1699  2200  智能电视
# 2   劲爆  X1000003  892.0  1218  4310  智能空调

# %%
DataFrame(data,columns=['商品名称','销售数量','销售价格'])
# Out:
#    商品名称  销售数量  销售价格
# 0   NaN  5303   998
# 1  智能电视  2200  1699
# 2  智能空调  4310  1218

# %%
data.to_csv('out1.csv')

# %%
data.to_csv('out2.csv',na_rep='NULL')

# %%
data.to_csv('out3.csv',na_rep='NULL',index=False,header=False)

# %%
data.to_csv('out4.csv',na_rep='NULL',index=False,header=False,columns=['销售热度','销售价格','销售数量'])

# %%
dates = pd.date_range('9/1/2017',periods=7)
dates
# Out:
# DatetimeIndex(['2017-09-01', '2017-09-02', '2017-09-03', '2017-09-04',
#                '2017-09-05', '2017-09-06', '2017-09-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
t = Series(np.arange(1,8),index=dates)
t
# Out:
# 2017-09-01    1
# 2017-09-02    2
# 2017-09-03    3
# 2017-09-04    4
# 2017-09-05    5
# 2017-09-06    6
# 2017-09-07    7
# Freq: D, dtype: int32

# %%
t.to_csv('out5.csv')

# %%
Series.from_csv('out5.csv')
# Out:
# 2017-09-01    1
# 2017-09-02    2
# 2017-09-03    3
# 2017-09-04    4
# 2017-09-05    5
# 2017-09-06    6
# 2017-09-07    7
# dtype: int64

# %%
import csv

# %%
f = open('ex7.csv')
reader = csv.reader(f)
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3', '4']

# %%
lines = list(csv.reader(open('ex7.csv')))
header,values = lines[0],lines[1:]
data_dict = {h : v for h,v in zip(header,zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
class MyDialect(csv.Dialect):
        lineterminator='\n'
        delimiter = ';'
        quotechar = '"'
        quoting = csv.QUOTE_MINIMAL

# %%
with open('NewData.csv','w') as f:
    writer = csv.writer(f,dialect=MyDialect)
    writer.writerow(('One','Two','Three'))
    writer.writerow(tuple('123'))
    writer.writerow(tuple('456'))
    writer.writerow(tuple('789'))

# %%
pd.read_table('NewData.csv',sep=';')
# Out:
#    One  Two  Three
# 0    1    2      3
# 1    4    5      6
# 2    7    8      9

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"},
              {"name": "Katie", "age": 33, "pet": "Cisco"}]
}
"""

# %%
import json

# %%
result = json.loads(obj)
type(result)
# Out:
# dict

# %%
asjson = json.dumps(result)
type(asjson)
# Out:
# str

# %%
df = DataFrame(result['siblings'],columns=['name','age'])
df
# Out:
#     name  age
# 0  Scott   25
# 1  Katie   33

# %%
df_file = pd.read_csv('ex1.csv',encoding='gbk')
df_file
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调

# %%
df_file.to_pickle('my_pickle')

# %%
pd.read_pickle('my_pickle')
# Out:
#        商品编号  进货价格  销售价格  销售数量  商品名称
# 0  X1000001   782   998  5303  小米手机
# 1  X1000002  1248  1699  2200  智能电视
# 2  X1000003   892  1218  4310  智能空调
